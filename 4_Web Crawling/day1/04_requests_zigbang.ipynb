# %% [markdown]
# ### Zigbang 원룸 매물 데이터 수집

# %%
import pandas as pd
import requests

# %% [markdown]
# #### Process
#     - 동이름으로 위도 경도 구하기
#     - 위도 경도로 geohash 알아내기
#     - geohash로 매물 아이디 가져오기
#     - 매물 아이디로 매물 정보 가져오기

# %% [markdown]
# #### 1. 동이름으로 위도 경도 구하기

# %% [markdown]
# ##### 1) 웹페이지 분석 -> URL

# %% [markdown]
# url decode 해야함.

# %%
addr = '망원동' 
url = f'https://apis.zigbang.com/v2/search?leaseYn=N&q={addr}&serviceType=원룸'

# %% [markdown]
# ##### 2) Request

# %%
response = requests.get(url) 
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '{"success":true,"code":"200","items":[{"id":4002,"type":"address","name":"망원동","hint":"","description":"서울특별시 마포구 망원동","lat":37.556785583496094,"lng":126.9013442993164,"zoom":5,"polygon":[],"_score":null,"_source":{"name_length":3,"local1":"서울시","local2":"마포구","local3":"망원동","web_level":15,"web_lat":37.556785583496094,"web_lng":126.9013442993164,"app_level":15,"app_lat":37.556785583496094,"app_lng":126.9013442993164,"법정동코드":"1144012300"},"zoom_level":{"google":15,"daum":4},"zoom_level_v2":{"app":5,"web":4}}],"next":null,"limit":0}'

# %% [markdown]
# ##### 3) JSON으로 위도 경도

# %%
data =response.json()['items'][0]
lat, lng = data['lat'], data['lng']
lat, lng
# Out:
# (37.556785583496094, 126.9013442993164)

# %% [markdown]
# #### 2. 위도 경도로 geohash 알아내기

# %% [markdown]
# - install geohash2 package

# %%
# !pip install geohash2
# Out:
# Collecting geohash2
#   Downloading geohash2-1.1.tar.gz (15 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: docutils>=0.3 in c:\users\user\anaconda3\lib\site-packages (from geohash2) (0.18.1)
# Building wheels for collected packages: geohash2
#   Building wheel for geohash2 (setup.py): started
#   Building wheel for geohash2 (setup.py): finished with status 'done'
#   Created wheel for geohash2: filename=geohash2-1.1-py3-none-any.whl size=15554 sha256=652dc6a7cc8d690a0fea418180ceed6f158b98fe29b4beb678c2e93cc274bc9c
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\f6\7c\c4\1b3c6fea0ebc53bf730dc86bbee7a713d501455dfb4c1f0623
# Successfully built geohash2
# Installing collected packages: geohash2
# Successfully installed geohash2-1.1

# %%
import geohash2

# %%
geohash = geohash2.encode(lat, lng, precision=5) # precision (영역크기) : 커질수록 영역이 작아짐

# %% [markdown]
# #### 3. geohash로 매물 아이디 가져오기

# %% [markdown]
# ##### 1) 웹페이지 분석 -> URL

# %% [markdown]
# ##### 2) Request

# %%
url = f'https://apis.zigbang.com/v2/items?deposit_gteq=0&domain=zigbang&geohash={geohash}&needHasNoFiltered=true&rent_gteq=0&sales_type_in=전세|월세&service_type_eq=원룸'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '{"clusters":[],"items":[{"lat":37.52906722773659,"lng":126.89979535013029,"item_id":37623131},{"lat":37.52909970073633,"lng":126.89979459312606,"item_id":37685329},{"lat":37.52906835690067,"lng":126.89979220341945,"item_id":37699264},{"lat":37.52907043063867,"lng":126.89895677025405,"item_id":37828417},{"lat":37.529114633593,"lng":126.8969544383019,"item_id":37595863},{"lat":37.52958116768765,"lng":126.89696559700613,"item_id":37812771},{"lat":37.52971666566198,"lng":126.90669680068928,"item_id":37594373},{"lat":37.529771171651106,"lng":126.89883157642349,"item_id":37779193},{"lat":37.52978651330546,"lng":126.89729902051963,"item_id":37681821},{"lat":37.52979599877884,"lng":126.89796592584005,"item_id":37789981},{"lat":37.5292838473765,"lng":126.89734002478102,"item_id":37812120},{"lat":37.529880627745094,"lng":126.9075465149246,"item_id":37591840},{"lat":37.529875332357385,"lng":126.90690391597163,"item_id":37647361},{"lat":37.529376455935015,"lng":126.9069080014477,"item_id":37776332},{"lat":37.5293780989139,"lng":126.90690289472758,"item_id":37821042},{"lat":37.529415398520605,"lng":126.9069440832124,"item_id":37822875},{"lat":37.52938649542676,"lng":126.90757413834227,"item_id":37822954},{"lat":37.52941690352576,"lng":126.90753873197283,"item_id":37830915},{"lat":37.52939406858932,"lng":126.90690087554074,"item_id":37831419},{"lat":37.52939795827349,"lng":126.90723507173855,"item_id":37802231},{"lat":37.52941314615221,"lng":126.90662579275016,"item_id":37807450},{"lat":37.5297864345624,"lng":126.9074885647178,"item_id":37573837},{"lat":37.530597222390746,"lng":126.9076182276354,"item_id":37806009},{"lat":37.53128455052579,"lng":126.90694448688105,"item_id":37756478},{"lat":37.53077450000691,"lng":126.90693584762506,"item_id":37756629},{"lat":37.53087584452335,"lng":126.90751825926843,"item_id":37687435},{"lat":37.531396441605,"lng":126.90755230813907,"item_id":37732891},{"lat":37.531754865382034,"lng":126.90511219071695,"item_id":37545432},{"lat":37.531261601295135,"lng":126.90571938565232,"item_id":37733547},{"lat":37.53125664898473,"lng":126.90571238935863,"item_id":37777449},{"lat":37.5312749992637,"lng":126.9050877794379,"item_id":37815927},{"lat":37.531256130721744,"lng":126.90573500085792,"item_id":37840494},{"lat":37.53176633121119,"lng":126.89780101397041,"item_id":37805662},{"lat":37.532460146006414,"lng":126.90443434753038,"item_id":37738304},{"lat":37.532425381009354,"lng":126.90507765490783,"item_id":37809180},{"lat":37.532512384579455,"lng":126.89669746772884,"item_id":37725362},{"lat":37.53199751180422,"lng":126.89730966180849,"item_id":37725378},{"lat":37.532524089086984,"lng":126.9053193665212,"item_id":37791522},{"lat":37.53252971999111,"lng":126.90531614435008,"item_id":37819640},{"lat":37.53252456526784,"lng":126.90594140063119,"item_id":37823879},{"lat":37.53259270587698,"lng":126.89968789895877,"item_id":37769944},{"lat":37.53210089997441,"lng":126.89971408745724,"item_id":37784321},{"lat":37.53210100291405,"lng":126.90033105801281,"item_id":37811134},{"lat":37.53260272760054,"lng":126.89970793993182,"item_id":37820390},{"lat":37.532311222168474,"lng":126.90484801444941,"item_id":37803194},{"lat":37.53258020723523,"lng":126.89559185039231,"item_id":37708036},{"lat":37.53255941200881,"lng":126.89564290042414,"item_id":37820398},{"lat":37.53309202982014,"lng":126.89160578349728,"item_id":37807105},{"lat":37.533162194625376,"lng":126.89224116254377,"item_id":37680236},{"lat":37.53318370711328,"lng":126.89162227850784,"item_id":37682630},{"lat":37.53274635437451,"lng":126.9055919643895,"item_id":37563947},{"lat":37.53278205434581,"lng":126.89227491471316,"item_id":37603729},{"lat":37.53343043764022,"lng":126.90583680180917,"item_id":37629225},{"lat":37.533495270207716,"lng":126.90621515849347,"item_id":37699830},{"lat":37.533116535965625,"lng":126.90436231383225,"item_id":37609079},{"lat":37.533122431926365,"lng":126.90499248188637,"item_id":37623279},{"lat":37.5331363513117,"lng":126.90435976222275,"item ...

# %% [markdown]
# ##### 3) JSON으로 매물ID

# %%
items = response.json()['items']
print(items[:5])
ids = [item['item_id'] for item in items]
len(ids), ids[:5]
# Out:
# [{'lat': 37.52906722773659, 'lng': 126.89979535013029, 'item_id': 37623131}, {'lat': 37.52909970073633, 'lng': 126.89979459312606, 'item_id': 37685329}, {'lat': 37.52906835690067, 'lng': 126.89979220341945, 'item_id': 37699264}, {'lat': 37.52907043063867, 'lng': 126.89895677025405, 'item_id': 37828417}, {'lat': 37.529114633593, 'lng': 126.8969544383019, 'item_id': 37595863}]
# (581, [37623131, 37685329, 37699264, 37828417, 37595863])

# %% [markdown]
# #### 4. 매물 아이디로 매물 정보 가져오기

# %%
# 요청 id가 1000개 초과하면 에러 발생
url = 'https://apis.zigbang.com/v2/items/list'
params = {'domain': 'zigbang', 'item_ids':ids}
response = requests.post(url, params)
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '{"items":[{"item_id":37623131,"section_type":null,"images_thumbnail":"https://ic.zigbang.com/ic/items/37623131/1.jpg","sales_type":"월세","sales_title":"월세","deposit":1000,"rent":50,"size_m2":19.83,"공급면적":{"m2":19.83,"p":"6"},"전용면적":{"m2":19.83,"p":"6"},"계약면적":null,"room_type_title":null,"floor":"2","floor_string":"2","building_floor":"9","title":"당산동에서 이보다 좋은 매물 못찾습니다","is_first_movein":null,"room_type":"02","status":true,"tags":["추천"],"service_type":"원룸","random_location":{"lat":37.529074152070415,"lng":126.90041974950167},"manage_cost":"7","reg_date":"2023-08-11T12:23:15+09:00","is_new":false,"addressOrigin":{"local1":"서울시","local2":"영등포구","local3":"당산동4가","local4":"","fullText":"서울시 영등포구 당산동4가","localText":"영등포구 당산동4가"},"action":{"isRead":false,"readAt":null,"isInquired":false,"inquiredAt":null,"isRewarded":false,"rewardedAt":null,"isReported":false,"reportedAt":null,"isChecked":false,"checkedAt":null,"isZzim":false},"contract":"","address":"영등포구 당산동4가","is_zzim":false,"address1":"서울시 영등포구 당산동4가","address2":null,"address3":null,"item_bm_type":"ZIGBANG"},{"item_id":37685329,"section_type":null,"images_thumbnail":"https://ic.zigbang.com/ic/items/37685329/1.jpg","sales_type":"전세","sales_title":"전세","deposit":12000,"rent":0,"size_m2":26.45,"공급면적":{"m2":26.45,"p":"8"},"전용면적":{"m2":26.45,"p":"8"},"계약면적":null,"room_type_title":null,"floor":"7","floor_string":"7","building_floor":"9","title":"당산,구청역2,5.9호선도보5분편리한대중교통","is_first_movein":null,"room_type":"02","status":true,"tags":["추천"],"service_type":"원룸","random_location":{"lat":37.52959367432441,"lng":126.90039241824029},"manage_cost":"10","reg_date":"2023-08-14T11:20:49+09:00","is_new":false,"addressOrigin":{"local1":"서울시","local2":"영등포구","local3":"당산동4가","local4":"","fullText":"서울시 영등포구 당산동4가","localText":"영등포구 당산동4가"},"action":{"isRead":false,"readAt":null,"isInquired":false,"inquiredAt":null,"isRewarded":false,"rewardedAt":null,"isReported":false,"reportedAt":null,"isChecked":false,"checkedAt":null,"isZzim":false},"contract":"","address":"영등포구 당산동4가","is_zzim":false,"address1":"서울시 영등포구 당산동4가","address2":null,"address3":null,"item_bm_type":"ZIGBANG"},{"item_id":37699264,"section_type":null,"images_thumbnail":"https://ic.zigbang.com/ic/items/37699264/1.jpg","sales_type":"월세","sales_title":"월세","deposit":1000,"rent":50,"size_m2":19.83,"공급면적":{"m2":19.83,"p":"6"},"전용면적":{"m2":19.83,"p":"6"},"계약면적":null,"room_type_title":null,"floor":"2","floor_string":"2","building_floor":"9","title":"당산동에서 이보다 좋은 매물 못찾습니다","is_first_movein":null,"room_type":"02","status":true,"tags":["추천"],"service_type":"원룸","random_location":{"lat":37.52907224141889,"lng":126.90042709994647},"manage_cost":"7","reg_date":"2023-08-15T01:28:31+09:00","is_new":false,"addressOrigin":{"local1":"서울시","local2":"영등포구","local3":"당산동4가","local4":"","fullText":"서울시 영등포구 당산동4가","localText":"영등포구 당산동4가"},"action":{"isRead":false,"readAt":null,"isInquired":false,"inquiredAt":null,"isRewarded":false,"rewardedAt":null,"isReported":false,"reportedAt":null,"isChecked":false,"checkedAt":null,"isZzim":false},"contract":"","address":"영등포구 당산동4가","is_zzim":false,"address1":"서울시 영등포구 당산동4가","address2":null,"address3":null,"item_bm_type":"ZIGBANG"},{"item_id":37828417,"section_type":null,"images_thumbnail":"https://ic.zigbang.com/ic/items/37828417/1.jpg","sales_type":"전세","sales_title":"전세","deposit":21900,"rent":0,"size_m2":35.58,"공급면적":{"m2":35.58,"p":"10.8"},"전용면적":{"m2":28.42,"p":"8.6"},"계약면적":null,"room_type_title":null,"floor":"3","floor_string":"3","building_floor":"6","title":"2,5,9역세권 투룸 끝판왕o","is_first_movein":null,"room_type":"04","status":true,"tags":["추천"],"service_type":"빌라","random_location":{"lat":37.52910275237275,"lng":126.89954462341068},"manage_cost":"6","reg_date":"2023-08-23T15:08:10+09:00","is_new":true,"addressOrigin":{"local1":"서울시","local2":"영등포구","local3":"당산동4가","local4":"","fullText":"서울시 영등포구 당산동4가","localText":"영등포구 당산동4가"},"action":{"isRead":false,"readAt":null,"isInquired":false,"inquiredAt":null,"isRe ...

# %%
data = response.json()['items']
df = pd.DataFrame(data)
df.tail(2)
# Out:
#       item_id section_type                                images_thumbnail  \
# 579  37703323         None  https://ic.zigbang.com/ic/items/37703323/1.jpg
# 580  37836529         None  https://ic.zigbang.com/ic/items/37836529/1.jpg
#
#     sales_type sales_title  deposit  rent  size_m2  \
# 579         월세          월세     5000   160    63.97
# 580         월세          월세     5000   160    61.09
#
#                            공급면적                        전용면적  계약면적  \
# 579  {'m2': 63.97, 'p': '19.4'}  {'m2': 42.52, 'p': '12.9'}  None
# 580  {'m2': 61.09, 'p': '18.5'}  {'m2': 40.61, 'p': '12.3'}  None
#
#     room_type_title floor floor_string building_floor  \
# 579            None     3            3              6
# 580            None     고            고              6
#
#                           title is_first_movein room_type  status  tags  \
# 579     전입o 가좌역 도보5분 살기좋은 신축쓰리룸            None        05    True  [추천]
# 580  가좌역 역세권 신축  첫입주 투룸  반전세주차O            None        04    True    []
#
#     service_type                                    random_location  \
# 579           빌라  {'lat': 37.56928138330394, 'lng': 126.90986972...
# 580         오피스텔  {'lat': 37.569294099503416, 'lng': 126.9092488...
#
#     manage_cost                   reg_date  is_new  \
# 579           8  2023-08-12T09:50:21+09:00   False
# 580           8  2023-08-24T11:44:39+09:00    True
#
#                                          addressOrigin  \
# 579  {'local1': '서울시', 'local2': '마포구', 'local3': '...
# 580  {'local1': '서울특별시', 'local2': '마포구', 'local3':...
#
#                                                 action contract address  \
# 579  {'isRead': False, 'readAt': None, 'isInquired'...           마포구 중동
# 580  {'isRead': False, 'readAt': None, 'isInquired'...           마포구 중동
#
#      is_zzim    address1 address2 address3 item_bm_type
# 579    False  서울시 마포구 중동     None     None      ZIGBANG
# 580    False  서울시 마포구 중동     None     None      ZIGBANG

# %%
pd.options.display.max_columns = 40
df.tail(2)
# Out:
#       item_id section_type                                images_thumbnail  \
# 579  37703323         None  https://ic.zigbang.com/ic/items/37703323/1.jpg
# 580  37836529         None  https://ic.zigbang.com/ic/items/37836529/1.jpg
#
#     sales_type sales_title  deposit  rent  size_m2  \
# 579         월세          월세     5000   160    63.97
# 580         월세          월세     5000   160    61.09
#
#                            공급면적                        전용면적  계약면적  \
# 579  {'m2': 63.97, 'p': '19.4'}  {'m2': 42.52, 'p': '12.9'}  None
# 580  {'m2': 61.09, 'p': '18.5'}  {'m2': 40.61, 'p': '12.3'}  None
#
#     room_type_title floor floor_string building_floor  \
# 579            None     3            3              6
# 580            None     고            고              6
#
#                           title is_first_movein room_type  status  tags  \
# 579     전입o 가좌역 도보5분 살기좋은 신축쓰리룸            None        05    True  [추천]
# 580  가좌역 역세권 신축  첫입주 투룸  반전세주차O            None        04    True    []
#
#     service_type                                    random_location  \
# 579           빌라  {'lat': 37.56928138330394, 'lng': 126.90986972...
# 580         오피스텔  {'lat': 37.569294099503416, 'lng': 126.9092488...
#
#     manage_cost                   reg_date  is_new  \
# 579           8  2023-08-12T09:50:21+09:00   False
# 580           8  2023-08-24T11:44:39+09:00    True
#
#                                          addressOrigin  \
# 579  {'local1': '서울시', 'local2': '마포구', 'local3': '...
# 580  {'local1': '서울특별시', 'local2': '마포구', 'local3':...
#
#                                                 action contract address  \
# 579  {'isRead': False, 'readAt': None, 'isInquired'...           마포구 중동
# 580  {'isRead': False, 'readAt': None, 'isInquired'...           마포구 중동
#
#      is_zzim    address1 address2 address3 item_bm_type
# 579    False  서울시 마포구 중동     None     None      ZIGBANG
# 580    False  서울시 마포구 중동     None     None      ZIGBANG

# %%
df.columns
# Out:
# Index(['item_id', 'section_type', 'images_thumbnail', 'sales_type',
#        'sales_title', 'deposit', 'rent', 'size_m2', '공급면적', '전용면적', '계약면적',
#        'room_type_title', 'floor', 'floor_string', 'building_floor', 'title',
#        'is_first_movein', 'room_type', 'status', 'tags', 'service_type',
#        'random_location', 'manage_cost', 'reg_date', 'is_new', 'addressOrigin',
#        'action', 'contract', 'address', 'is_zzim', 'address1', 'address2',
#        'address3', 'item_bm_type'],
#       dtype='object')

# %%
columns = ['item_id', 'sales_type', 'deposit', 'rent', 'size_m2', 
          'floor', 'floor_string', 'building_floor', 'title',
          'service_type', 'manage_cost', 'address1']
df = df[columns]
df.tail(2)
# Out:
#       item_id sales_type  deposit  rent  size_m2 floor floor_string  \
# 579  37703323         월세     5000   160    63.97     3            3
# 580  37836529         월세     5000   160    61.09     고            고
#
#     building_floor                       title service_type manage_cost  \
# 579              6     전입o 가좌역 도보5분 살기좋은 신축쓰리룸           빌라           8
# 580              6  가좌역 역세권 신축  첫입주 투룸  반전세주차O         오피스텔           8
#
#        address1
# 579  서울시 마포구 중동
# 580  서울시 마포구 중동

# %%
df['address1']
# Out:
# 0      서울시 영등포구 당산동4가
# 1      서울시 영등포구 당산동4가
# 2      서울시 영등포구 당산동4가
# 3      서울시 영등포구 당산동4가
# 4      서울시 영등포구 당산동4가
#             ...
# 576       서울시 마포구 성산동
# 577       서울시 마포구 성산동
# 578       서울시 마포구 성산동
# 579        서울시 마포구 중동
# 580        서울시 마포구 중동
# Name: address1, Length: 581, dtype: object

# %%
result = df[df['address1'].str.contains('망원동')].reset_index(drop=True) 
result.tail(2)
# Out:
#      item_id sales_type  deposit  rent  size_m2 floor floor_string  \
# 57  37804362         월세      300    72    19.83     2            2
# 58  37811722         월세     2000   110    48.00     1            1
#
#    building_floor                title service_type manage_cost     address1
# 57              3     신축급즉시입주깔끔원룸 주차가능           원룸           7  서울시 마포구 망원동
# 58              3  리모델링후 첫입주 쓰리룸월세 풀옵션           빌라           1  서울시 마포구 망원동

# %%
def oneroom(addr): 
    
    url = f'https://apis.zigbang.com/v2/search?leaseYn=N&q={addr}&serviceType=원룸' 
    response = requests.get(url) 
    data = response.json()['items'][0]
    lat, lng = data['lat'], data['lng'] 
    geohash = geohash2.encode(lat, lng, precision=5) 
    
    url = f'https://apis.zigbang.com/v2/items?deposit_gteq=0&domain=zigbang&geohash={geohash}&needHasNoFiltered=true&rent_gteq=0&sales_type_in=전세|월세&service_type_eq=원룸' 
    response = requests.get(url)
    items = response.json()['items'] 
    ids = [item['item_id'] for item in items]
    
    url = 'https://apis.zigbang.com/v2/items/list' 
    params = {'domain': 'zigbang', 'item_ids': ids} 
    response = requests.post(url, params) 
    data = response.json()['items'] 
    df = pd.DataFrame(data) 
    result = df[df['address1'].str.contains('망원동')].reset_index(drop=True) 
    return result[['item_id', 'title', 'deposit', 'rent', 'address1', 'size_m2', 'manage_cost']]

# %%
result = oneroom('마포구 합정동')
result.tail(2)
# Out:
# <Response [200]>
#      item_id                title  deposit  rent     address1  size_m2  \
# 57  37804362     신축급즉시입주깔끔원룸 주차가능      300    72  서울시 마포구 망원동    19.83
# 58  37811722  리모델링후 첫입주 쓰리룸월세 풀옵션     2000   110  서울시 마포구 망원동    48.00
#
#    manage_cost
# 57           7
# 58           1

# %% [markdown]
# Spectial Command

# %%
# %whos
# Out:
# Variable   Type         Data/Info
# ---------------------------------
# addr       str          망원동
# columns    list         n=12
# data       list         n=581
# df         DataFrame          item_id sales_type <...>\n[581 rows x 12 columns]
# geohash    str          wydjx
# geohash2   module       <module 'geohash2' from '<...>\\geohash2\\__init__.py'>
# ids        list         n=581
# items      list         n=581
# lat        float        37.556785583496094
# lng        float        126.9013442993164
# oneroom    function     <function oneroom at 0x000001774A853E20>
# params     dict         n=2
# pd         module       <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# requests   module       <module 'requests' from '<...>\\requests\\__init__.py'>
# response   Response     <Response [200]>
# result     DataFrame         item_id sales_type  <...>         1  서울시 마포구 망원동
# url        str          https://apis.zigbang.com/v2/items/list

# %%
# %reset

# %% [markdown]
# ##### 모듈 파일 만들기
#
# : 변수, 함수, 클래스를 하나의 파일(.py)로 묶어서 코드 작성 실행

# %%
# %%writefile zigbang.py
import pandas as pd 
import requests 
import geohash2

def oneroom(addr): 
    
    url = f'https://apis.zigbang.com/v2/search?leaseYn=N&q={addr}&serviceType=원룸' 
    response = requests.get(url) 
    data = response.json()['items'][0]
    lat, lng = data['lat'], data['lng'] 
    geohash = geohash2.encode(lat, lng, precision=5) 
    
    url = f'https://apis.zigbang.com/v2/items?deposit_gteq=0&domain=zigbang&geohash={geohash}&needHasNoFiltered=true&rent_gteq=0&sales_type_in=전세|월세&service_type_eq=원룸' 
    response = requests.get(url)
    items = response.json()['items'] 
    ids = [item['item_id'] for item in items]
    
    url = 'https://apis.zigbang.com/v2/items/list' 
    params = {'domain': 'zigbang', 'item_ids': ids} 
    response = requests.post(url, params) 
    data = response.json()['items'] 
    df = pd.DataFrame(data) 
    result = df[df['address1'].str.contains('망원동')].reset_index(drop=True) 
    return result[['item_id', 'title', 'deposit', 'rent', 'address1', 'size_m2', 'manage_cost']]
# Out:
# Writing zigbang.py

# %%
# %ls zigbang.py
# Out:
#  C 드라이브의 볼륨: WINDOWS
#  볼륨 일련 번호: 1CE2-C115
#
#  C:\Users\user\AIVLE\4_web\day1 디렉터리
#
# 2023-08-24  오후 05:07             1,061 zigbang.py
#                1개 파일               1,061 바이트
#                0개 디렉터리  165,159,800,832 바이트 남음
