# %% [markdown]
# # **이변량분석 - 숫자 vs 범주**

# %% [markdown]
# ## **1.환경준비**

# %% [markdown]
# * 라이브러리 불러오기

# %%
import pandas as pd
import numpy as np
import random as rd

import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.mosaicplot import mosaic      #mosaic plot!

import scipy.stats as spst

# %% [markdown]
# * 데이터 불러오기 : 다음의 예제 데이터를 사용합니다.
# > 타이타닉 생존자

# %%
# 타이타닉 데이터
titanic = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/titanic.1.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass Title     Sex   Age  SibSp  Parch  \
# 0            1         0       3    Mr    male  22.0      1      0
# 1            2         1       1   Mrs  female  38.0      1      0
# 2            3         1       3  Miss  female  26.0      0      0
# 3            4         1       1   Mrs  female  35.0      1      0
# 4            5         0       3    Mr    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked AgeGroup  Family  Mother    Fare2
# 0         A/5 21171   7.2500   NaN        S   Age_20       2       0   7.2500
# 1          PC 17599  71.2833   C85        C   Age_30       2       0  71.2833
# 2  STON/O2. 3101282   7.9250   NaN        S   Age_20       1       0   7.9250
# 3            113803  53.1000  C123        S   Age_30       2       0  53.1000
# 4            373450   8.0500   NaN        S   Age_30       1       0   8.0500

# %% [markdown]
# ## **2.숫자 --> 범주**

# %% [markdown]
# ### **(1) 시각화**

# %% [markdown]
# * 히스토그램을 Survived로 나눠서 그려봅시다.

# %%
sns.histplot(x='Age', data = titanic, hue = 'Survived')
plt.show()

# %% [markdown]
# * kdeplot을 그려봅시다.
# * 두가지 방법이 있습니다.
#     * ① kdeplot(   , hue = 'Survived')
#         * 생존여부의 비율이 유지된 채로 그려짐
#         * 두 그래프의 아래 면적의 합이 1
#     * ② kdeplot(   , hue = 'Survived', common_norm = False)
#         * 생존여부 각각 아래 면적의 합이 1인 그래프
#     * ③ kdeplot(   , hue = 'Survived', multiple = 'fill')
#         * 나이에 따라 생존여부 **비율**을 비교해볼 수 있음. (양의 비교가 아닌 비율!)

# %% [markdown]
# ① kdeplot( , hue = 'Survived)
#
# * common_norm = True (기본값)

# %%
sns.kdeplot(x='Age', data = titanic, hue ='Survived')
plt.show()

# %% [markdown]
# common_norm이 True일 때,
#
# ![image.png](attachment:69bdde66-3244-4699-ab69-a3009e8f851c.png)

# %% [markdown]
# ② kdeplot( , hue = 'Survived, common_norm = False)

# %%
sns.kdeplot(x='Age', data = titanic, hue ='Survived', 
            common_norm = False)
plt.show()

# %% [markdown]
# ![image.png](attachment:f144040f-9e4c-48ff-9f6e-afcc5ef4f35b.png)

# %% [raw]
# 겹치는 부분은 전체 평균과 같은 지점
#
# 따라서, 겹치는 부분이 많을수록 관련이(차이가) 전혀없다

# %% [markdown]
# ![image.png](attachment:8128d006-e4a0-4b69-81ba-ee5cea2dfc81.png)

# %% [markdown]
# ③ multiple = 'fill' 옵션

# %%
sns.kdeplot(x='Age', data = titanic, hue ='Survived'
            , multiple = 'fill')
plt.axhline(titanic['Survived'].mean(), color = 'r')
plt.show()

# %% [markdown]
# ![image.png](attachment:4236aa27-1eb9-4cc0-a7c6-22889fe52d36.png)

# %%
sns.histplot(x='Age', data = titanic, bins = 16
             , hue ='Survived', multiple = 'fill')
plt.axhline(titanic['Survived'].mean(), color = 'r')
plt.show()

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# 다음의 관계에 대해 시각화 해 봅시다.

# %% [markdown]
# * [문1] Fare(운임) --> Survived

# %%
def visualize(var, targ):
    print("common_norm = True 일 때 KDE")
    sns.kdeplot(x='Fare', data=titanic, hue='Survived')
    plt.show()
    
    print('='*100)
    print("common_norm = False 일 때 KDE")
    sns.kdeplot(x='Fare', data=titanic, hue='Survived', common_norm = False)
    plt.show()
    
    print('='*100)
    print("multiple = fill 일 때 KDE")
    sns.kdeplot(x='Fare', data=titanic, hue='Survived', multiple="fill")
    plt.show()

# %%
visualize('Fare', 'Survived')
# Out:
# common_norm = True 일 때 KDE
# ...
# common_norm = False 일 때 KDE
# ...
# multiple = fill 일 때 KDE

# %%
var = 'Fare' 

plt.figure(figsize = (6,12))
plt.subplot(3, 1, 1) 
sns.kdeplot(x= var, data = titanic, hue ='Survived', common_norm = False) 
plt.xlim(0, 520) 

plt.subplot(3, 1, 2) 
sns.kdeplot(x=var, data = titanic, hue ='Survived' , multiple = 'fill') 
plt.axhline(titanic['Survived'].mean(), color = 'r') 
plt.xlim(0, 520) 


plt.subplot(3, 1, 3) 
sns.histplot(x=var, data = titanic, bins = 16, hue ='Survived', multiple = 'fill') 
plt.axhline(titanic['Survived'].mean(), color = 'r') 
plt.xlim(0, 520) 
plt.tight_layout() 
plt.show()
