# %% [markdown]
# # **저시력자를 위한 원화 화폐 분류**
# ---
# - 본 과제는 UltraLytics YOLO v5 모델 사용을 권장합니다.
#     - 본 파일의 목차는 UltraLytics YOLO v5에 맞게 작성되어 있습니다.
#     - 다른 모델을 찾아서 사용하셔도 좋습니다.
#     - 산출물이 잘 나오면 됩니다 : )
# ---

# %% [markdown]
# ## 0.미션
# ---
# - **과제 수행 목표**
#     - 본 과제는 Object Detection 문제입니다.
#     - Object Detection 문제로 접근하기 위해 **데이터셋 전처리**를 하셔야 합니다.
#     - 데이터셋 : money_dataset.zip
#         1. 데이터셋은 압축 파일로 제공됩니다.
#         2. 압축 파일 안에는 화폐마다 폴더가 개별적으로 존재합니다.
#         3. 폴더 안에는 화폐 이미지와 화폐 정보가 담긴 json 파일이 있습니다.
#     - 여러분이 직접 촬영한 화폐 사진들을 탐지 과정에서 이용 해보세요.
#     - 이미지에 화폐 하나만 나오게 촬영하는 것은 지양해주세요.
#     - 다양한 방법으로 화폐를 촬영하고 결과를 확인해보세요.
#         - ex 1) 화폐의 모든 종류를 한 이미지에 나오게 촬영
#         - ex 2) 여러 화폐를 겹치게 하여 촬영
# ---
# - **Key Point**
#     1. 모델에 맞는 폴더 구조 확인
#     2. 이미지 축소 비율에 맞춰 좌표값 변경
#         - 좌표를 이미지 리사이즈한 비율로 변경
#     3. 모델에 맞는 정보 추출/형식 변경
#         - json 파일에서 정보 추출 및 모델 형식에 맞게 변경
#     4. 화폐당 하나의 클래스로 변경
#         - 총 8개 클래스
#     5. 모델 선택 필요
# ---

# %% [markdown]
# ## 1.환경설정

# %% [markdown]
# ### (1) 구글 드라이브 연동, 데이터 다운로드
# ---
# - 아래의 코드 셀을 반드시 실행시켜야 합니다.
# ---

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (4.6.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.12.2)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2023.7.22)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)

# %% [markdown]
# ### (2) 데이터셋 불러오기
# ---
# - **세부요구사항**
#     - 데이터셋 파일의 압축을 해제하세요.
# ---
# - 예제 코드에서는 zipfile 모듈을 이용하였습니다.
#     - [zipfile document](https://docs.python.org/3/library/zipfile.html#zipfile-objects)
#     - 해당 모듈 이외에 자신이 잘 알고 있는 방법을 사용해도 됩니다.
# ---

# %%
import zipfile, gdown,os

# %%
import zipfile, gdown,os
url ="https://drive.google.com/file/d/1k1tXDK35s6BsMTPGWSl5GVGNoPfC898X/view?usp=drive_link"
file_name = "money_dataset.zip"
output = "/content/drive/MyDrive/" + file_name # 변경 가능
if not os.path.exists(output):
    gdown.download(url=url, output=output, quiet=False, fuzzy=True)

# %%
# 데이터셋 압축 파일 경로 : 유저별로 상이할 수 있음
money_data = zipfile.ZipFile(output)

# %%
# 데이터셋 압축 해제
money_data.extractall('/content/Dataset/')

# %% [markdown]
# ## 2.데이터 전처리

# %% [markdown]
# ### (1) 폴더 구조 생성 및 파일 이동
# ---
# - **세부요구사항**
#     -  모델에서 요구하는 폴더 구조를 만들어야 합니다.
#         - Hint : Image와 Label을 구분하는 폴더를 만들어 주세요
# ---
# - 예제 코드에서는 glob, shutil 모듈을 이용하였습니다.
#     - [glob document](https://docs.python.org/3/library/glob.html) | [shutil document](https://docs.python.org/3/library/shutil.html)
#     - 해당 모듈 이외에 자신이 잘 알고 있는 방법을 사용해도 됩니다.
# ---

# %%
# 1.폴더 구조 만들기
# !mkdir /content/Dataset/images;
# !mkdir /content/Dataset/images/train; mkdir /content/Dataset/images/val

# !mkdir /content/Dataset/labels;
# !mkdir /content/Dataset/labels/train; mkdir /content/Dataset/labels/val

# %%
import glob, shutil
from sklearn.model_selection import train_test_split
import cv2
import json
import numpy as np

# %%
# 2. Dataset metadata 입력
won_list = [ '10', '50', '100', '500', '1000', '5000', '10000', '50000']
data_path = '/content/Dataset/'

# %% [markdown]
# ---
# - 데이터를 Training set | Validation set으로 분할하세요.
#     - 예시 : Training과 Validation은 8:2로 분리
# - Hint : 이미지 데이터는 /images에, JSON 데이터는 /labels에 넣어주세요
#     - 예시 : /dataset/images/train, /dataset/labels/train
#     - 예제 코드에서는 glob, shutil 모듈을 이용하였습니다.
#     - [glob document](https://docs.python.org/3/library/glob.html) | [shutil document](https://docs.python.org/3/library/shutil.html)
#
#     ※ 해당 모듈 이외에 자신이 잘 알고 있는 방법을 사용해도 됩니다.
#
# ---

# %%
########################
# 이 셀부터 코드 작성하세요
########################
# 3. 데이터를 Training set | Validation set으로 분할하세요.

# 디렉토리 내에서 확장자가 .img인 파일을 찾음
def read_json(json_path):
    with open(json_path, 'r') as f:
        json_file = json.load(f)
    return json_file

def move_files(file_list, src_path, dst_path_train, dst_path_val):
    for file in file_list:
        print(file, 'file 입니다')
        # /content/Dataset/100/100_1000_1.jpg
        image = file.split('/')[-1] + '.jpg'
        json = file.split('/')[-1] + '.json'
        rotated_image = file.split('/')[-1] + '_rotated.jpg'
        rotated_json = file.split('/')[-1] + '_rotated.json'


        shutil.copy(os.path.join(src_path ,image), dst_path_train)
        shutil.copy(os.path.join(src_path, json), dst_path_val)

        shutil.copy(os.path.join(src_path ,rotated_image), dst_path_train)
        shutil.copy(os.path.join(src_path, rotated_json), dst_path_val)

def rotate_image_and_box(image_path, json_file, angle=90):
    # 이미지 읽기
    image = cv2.imread(image_path)
    print(image)
    h, w = image.shape[:2]


    # 이미지 중심점을 기준으로 90도 회전
    M = cv2.getRotationMatrix2D((w//2, h//2), angle, 1)
    rotated_image = cv2.warpAffine(image, M, (w, h))

    # bounding box 좌표도 회전
    shape = json_file['shapes'][0]
    x1, y1 = shape['points'][0]
    x2, y2 = shape['points'][1]

    box_center = np.array([[(x1 + x2) / 2, (y1 + y2) / 2]], dtype='float32')
    box_center = np.column_stack((box_center, np.ones(box_center.shape[0], dtype='float32')))

    rotated_center = np.dot(M, box_center.T).T
    rotated_x, rotated_y = rotated_center[0][:2]

    # 회전된 bounding box의 새로운 좌표 계산
    new_x1, new_y1 = rotated_x - abs(x1 - x2) / 2, rotated_y - abs(y1 - y2) / 2
    new_x2, new_y2 = rotated_x + abs(x1 - x2) / 2, rotated_y + abs(y1 - y2) / 2

    # 회전된 이미지와 bounding box 좌표 반환
    return rotated_image, [[new_x1, new_y1], [new_x2, new_y2]]

# %%
# 지폐 선택 - 10, 100, 500, ...
for won in won_list:
    # src 경로 설정
    src_path = data_path + won + '/'

    # 저장할 파일 설정
    train_images = '/content/Dataset/images/train'
    val_imgaes = '/content/Dataset/images/val'
    train_json = '/content/Dataset/labels/train'
    val_json = '/content/Dataset/labels/val'

    # 데이터를 나누기 위해 파일 이름 불러오기
    image_files = glob.glob(os.path.join(src_path, '*.jpg'))
    images = [name.replace('.jpg', '') for name in image_files]

    for img in image_files:
        image_path = img
        json_path = image_path.replace('.jpg', '.json') # 파일명
        json_file = read_json(json_path) # 파일을 json 으로 읽음
        rotated_image, rotated_box =  rotate_image_and_box(image_path, json_file)

        # rotated_image_filename = os.path.splittext(file)[0] + '_rotated.jpg'
        rotated_image_filename = image_path.replace('.jpg', '_rotated.jpg')
        cv2.imwrite(os.path.join(src_path, rotated_image_filename), rotated_image)


        json_file['shapes'][0]['points'] = rotated_box
        json_file['imageWidth'], json_file['imageHeight'] = json_file['imageHeight'], json_file['imageWidth']
        # rotated_json_filename = os.path.splitext(file)[0] + '_rotated.json'
        rotated_json_path = json_path.replace('.json', '_rotated.json')
        # print(rotated_json_path)
        with open(rotated_json_path, 'w') as f:
            json.dump(json_file, f)

    # 데이터 나누기
    train_names, val_names = train_test_split(images, test_size=0.2,random_state=2023, shuffle=True)
    move_files(train_names, src_path, train_images, train_json)
    move_files(val_names, src_path, val_imgaes, val_json)

# %% [markdown]
# yolo5/detect.py의 default 파라미터를 조정해서 학습할 수 있음.

# %% [markdown]
# ### (2) json에서 정보 추출
# ---
# - **세부요구사항**
#     - json 파일에서 필요한 정보를 추출하세요:
#         - 위치 정보 : x1, x2, y1, y2
#         - 박스 정보 : shape_type
#         - 클래스 정보 : labels
#     - 화폐당 하나의 클래스로 변경하세요.
#         - json 파일에는 화폐 클래스가 앞뒷면으로 구분되어 있습니다.
#         - 화폐의 앞뒷면 구분을 없애주세요.
#             - 예시 : 'ten_front', 'ten_back' -> 'ten'
#     - 화폐의 위치 정보를 YOLO 모델 형식에 맞게 변경 해주세요.
#         - 사용되는 이미지는 원본에서 1/5로 축소되어 있습니다.
#         - json 파일의 정보는 원본 기준 데이터이므로 위치 정보 추출을 할 때 x값과 y값을 1/5로 줄여주세요.
#     - 이렇게 변경된 정보를 YOLO label 형식에 맞게 txt파일로 저장 해 주세요.
#         - Hint : YOLO Labeling Format [label, x-center, y-center, width-norm, height-norm]
# ---

# %%
import os, json

# %%
json_path = '/content/Dataset/labels/'
temp_list = ['train', 'val']

# %%
########################
# 이 셀부터 코드 작성하세요
# Json 파일에서 필요한 정보만 골라 txt로 바꾸는 작업임을 기억하세요!
########################
money_class = ['Ten' ,'Fifty', 'Hundred', 'Five_Hundred', 'Thousand', 'Five_Thousand', 'Ten_Thousand', 'Fifty_Thousand']


result =  ''

# 데이터를 나누기 위해 파일 이름 불러오기
for end in temp_list:
    image_files = glob.glob(os.path.join(json_path, end, '*.json'))
    print(len(image_files))
    count = 0
    for file in image_files:
        text = file.replace('.json', '')
        with open(file, 'r') as json_file:
            data = json.load(json_file)

        # 파일 이름
        text_name = text.split("/")[-1]
        # 라벨
        tmp = '_'.join(data['shapes'][0]['label'].split('_')[:-1])
        label = money_class.index(tmp)

        # x1
        x1 = data['shapes'][0]['points'][0][0]
        # y1
        y1 = data['shapes'][0]['points'][0][1]
        # x2
        x2 = data['shapes'][0]['points'][1][0]
        # y2
        y2 = data['shapes'][0]['points'][1][1]

        # ih
        ih = data['imageHeight'] / 5
        # iW
        iw = data['imageWidth'] / 5


        X = ((x1+x2)/2) / 5 / iw
        Y = ((y1+y2)/2) / 5 / ih

        # H
        H = (y2- y1) /5 / ih
        # W
        W = (x2-x1) / 5 / iw

        tmp = [label, X, Y, W, H]

        result = ' '.join(map(str, tmp))

        # 파일 경로 설정 (원하는 경로와 파일명을 지정하세요)
        file_path = data_path + 'labels/' + end +'/'+ text_name + '.txt'

        # 텍스트 파일로 문자열 저장
        with open(file_path, "w", encoding="utf-8") as text_file:
            text_file.write(result)
        os.remove(file)

        count += 1
    print(count)
# Out:
# 8344
# 8344
# 2092
# 2092

# %% [markdown]
# ### (3) 데이터셋 정보가 담긴 파일 생성
# ---
# - **세부요구사항**
#     - 파일 안에 있어야 할 정보는 아래와 같습니다.
#         - 학습할 클래스 이름 정보
#         - 학습할 클래스 수 정보
#         - Training, Validation 데이터셋 위치 정보
# ---
# - 가장 대중적으로 이용하는 라이브러리는 yaml 입니다.
#     - [yaml document](https://pyyaml.org/wiki/PyYAMLDocumentation)
#     - 해당 모듈 이외에 자신이 잘 알고 있는 방법을 사용해도 됩니다.
# ---

# %%
import yaml

# %%
won_dict = {0:'10', 1:'50', 2:'100', 3:'500', 4:'1000', 5:'5000', 6:'10000', 7:'50000'}

# %%
########################
# 이 셀부터 코드 작성하세요
########################
import yaml

yaml_data = {"names": won_dict,
             "nc":8,
             "train": '/content/Dataset/images/train',
             "val": '/content/Dataset/images/val'
             }

with open('/content/Dataset/money.yaml', "w") as f:
  yaml.dump(yaml_data, f)

# %% [markdown]
# ## 3.모델링

# %% [markdown]
# ### (1) 모델 라이브러리 설치
# ---

# %% [markdown]
# yolov5가 stable한 버전이라 v5를 사용하겠다. docs에도 매우 자세히 나와있음.
#
# https://docs.ultralytics.com/yolov5/

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# !pip install -r yolov5/requirements.txt  # install
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15994, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 15994 (delta 18), reused 18 (delta 12), pack-reused 15967
# Receiving objects: 100% (15994/15994), 14.64 MiB | 18.09 MiB/s, done.
# Resolving deltas: 100% (10980/10980), done.
# Collecting gitpython>=3.1.30 (from -r yolov5/requirements.txt (line 5))
#   Downloading GitPython-3.1.37-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 6)) (3.7.1)
# Requirement already satisfied: numpy>=1.22.2 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 7)) (1.23.5)
# Requirement already satisfied: opencv-python>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 8)) (4.8.0.76)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 9)) (9.4.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 10)) (5.9.5)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 11)) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 12)) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 13)) (1.11.2)
# Collecting thop>=0.1.1 (from -r yolov5/requirements.txt (line 14))
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 15)) (2.0.1+cu118)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 16)) (0.15.2+cu118)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 17)) (4.66.1)
# Collecting ultralytics>=8.0.147 (from -r yolov5/requirements.txt (line 18))
#   Downloading ultralytics-8.0.186-py3-none-any.whl (618 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 618.4/618.4 kB 25.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 27)) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 28)) (0.12.2)
# Requirement already satisfied: setuptools>=65.5.1 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 42)) (67.7.2)
# Collecting gitdb<5,>=4.0.1 (from gitpython>=3.1.30->-r yolov5/requirements.txt (line 5))
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.6 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 12)) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 12)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 12)) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 12)) (2023.7.22)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (16.0.6)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics>=8.0.147->-r yolov5/requirements.txt (line 18)) (9.0.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->-r yolov5/requirements.txt (line 27)) (2023.3.post1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r yolov5/requirements.txt (line 5))
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (1.3.0)
# Installing collected packages: smmap, gitdb, gitpython, ultralytics, thop
# Successfully installed gitdb-4.0.10 gitpython-3.1.37 smmap-5.0.1 thop-0.1.1.post2209072238 ultralytics-8.0.186

# %% [markdown]
# ### (2) 가중치 파일 다운로드
# ---
# - **세부요구사항**
#     - 모델 개발자가 제공하는 사전 학습 가중치 파일을 다운로드 하세요.
#         - 해당 과정이 불필요하다면 넘어가셔도 됩니다!
# ---

# %%
# Freeze Backbone - 학습 속도 향상
# !python train.py --freeze 10

# %%
########################
# 이 셀부터 코드 작성하세요
########################

# %% [markdown]
# ### (3) 학습 : train.py
# ---
# - **세부요구사항**
#     - UltraLytics YOLO v5에는 아래의 데이터가 필요합니다.
#         - 데이터셋 정보가 담긴 yaml 파일
#         - 사용하려는 모델 구조에 대한 yaml 파일
#         - 사용하려는 모델의 가중치 파일
# ---

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
########################
# 이 셀부터 코드 작성하세요
########################
9_rotated.jpg: ignoring corrupt image/label: negative label values [   -0.25518]
# val: WARNING ⚠️ /content/Dataset/images/val/50_963_9_rotated.jpg: ignoring corrupt image/label: negative label values [   -0.31649]
# val: WARNING ⚠️ /content/Dataset/images/val/50_968_9_rotated.jpg: ignoring corrupt image/label: negative label values [   -0.19762]
# val: WARNING ⚠️ /content/Dataset/images/val/50_972_1_rotated.jpg: ignoring corrupt image/label: negative label values [   -0.26284]
# val: WARNING ⚠️ /content/Dataset/images/val/50_975_9_rotated.jpg: ignoring corrupt image/label: negative label values [   -0.26746]
# val: WARNING ⚠️ /content/Dataset/images/val/50_982_9_rotated.jpg: ignoring corrupt image/label: negative label values [    -0.3172]
# val: WARNING ⚠️ /content/Dataset/images/val/50_999_9_rotated.jpg: ignoring corrupt image/label: negative label values [   -0.26208]
# val: New cache created: /content/Dataset/labels/val.cache
# val: Caching images (0.8GB ram): 100% 1046/1046 [00:03<00:00, 262.26it/s]
#
# AutoAnchor: 4.01 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp2/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/train/exp2
# Starting training for 10 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         0/9      13.4G     0.0102    0.00338   0.002145        113        640: 100% 87/87 [00:53<00:00,  1.62it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:11<00:00,  1.02s/it]
#                    all       1046       1046      0.997      0.999      0.994      0.974
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         1/9      11.4G   0.009747   0.003188   0.002211        105        640: 100% 87/87 [00:48<00:00,  1.80it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:10<00:00,  1.08it/s]
#                    all       1046       1046      0.999          1      0.994      0.971
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         2/9      11.4G   0.009298   0.003146   0.002682        101        640: 100% 87/87 [00:48<00:00,  1.81it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:10<00:00,  1.09it/s]
#                    all       1046       1046      0.998      0.999      0.995      0.979
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         3/9      11.4G   0.008643     0.0031    0.00313         99        640: 100% 87/87 [00:48<00:00,  1.81it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:10<00:00,  1.09it/s]
#                    all       1046       1046      0.998          1      0.995       0.97
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         4/9        14G   0.008556   0.003061   0.003275         95        640: 100% 87/87 [00:48<00:00,  1.81it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:10<00:00,  1.09it/s]
#                    all       1046       1046      0.995      0.999      0.995      0.987
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         5/9        14G   0.007807   0.003016    0.00303         92        640: 100% 87/87 [00:48<00:00,  1.81it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:10<00:00,  1.10it/s]
#                    all       1046       1046      0.999          1      0.995      0.988
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         6/9        14G   0.007147   0.002763   0.002538        102        640: 100% 87/87 [00:48<00:00,  1.80it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:10<00:00,  1.10it/s]
#                    all       1046       1046      0.999          1      0.995       0.99
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         7/9        14G   0.006491   0.002649   0.002967         98        640: 100% 87/87 [00:48<00:00,  1.81it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:10<00:00,  1.09it/s]
#                    all       1046       1046      0.999          1      0.995      0.989
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         8/9        14G   0.005577   0.002457   0.002308         95        640: 100% 87/87 [00:48<00:00,  1.81it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:10<00:00,  1.10it/s]
#                    all       1046       1046      0.999          1      0.995      0.993
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         9/9        14G   0.005043   0.002263   0.002138         93        640: 100% 87/87 [00:48<00:00,  1.81it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:10<00:00,  1.09it/s]
#                    all       1046       1046      0.998          1      0.995      0.994
#
# 10 epochs completed in 0.170 hours.
# Optimizer stripped from runs/train/exp2/weights/last.pt, 173.1MB
# Optimizer stripped from runs/train/exp2/weights/best.pt, 173.1MB
#
# Validating runs/train/exp2/weights/best.pt...
# Fusing layers...
# Model summary: 322 layers, 86220517 parameters, 0 gradients, 203.9 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:13<00:00,  1.19s/it]
#                    all       1046       1046      0.998          1      0.995      0.994
#                     10       1046         88      0.999          1      0.995      0.992
#                     50       1046         88      0.999          1      0.995      0.993
#                    100       1046         88      0.999          1      0.995      0.993
#                    500       1046         88      0.999          1      0.995      0.993
#                   1000       1046        172      0.999          1      0.995      0.995
#                   5000       1046        174      0.999          1      0.995      0.995
#                  10000       1046        174      0.994          1      0.995      0.995
#                  50000       1046        174          1          1      0.995      0.994
# Results saved to runs/train/exp2

# %% [markdown]
# ## 4.탐지 : detect.py
# ---
# - **세부요구사항**
#     - 학습 과정에서 생성된 가중치 파일을 이용하세요.
#     - IoU threshold를 0.25 이하로 설정하세요.
#     - confidence threshold를 0.75 이상으로 설정하세요.
# ---
# - 여러분이 **직접 촬영한 화폐 사진과 동영상**을 탐지 과정에 이용하여 결과를 확인하세요.
#     - 조건
#         1. 화폐의 수를 늘려가며 촬영 해보세요.
#             - ex) 50원 하나, 50원 둘, 50원 셋, ...
#         2. 화폐의 종류를 늘려가며 촬영 해보세요.
#             - ex) 50원 하나와 100원 하나, 50원 하나와 100원 하나와 1000원 하나, ...
#         3. 사진은 최소 30장 이상, 동영상은 최소 하나 이상 촬영하여 사용 해보세요.
# ---

# %%
# test
# python val.py --weights yolov5x.pt --data coco.yaml --img 640 --half

# %%
# 기본 사용
# python detect.py --weights yolov5s.pt --source 0                               # webcam
#                                                img.jpg                         # image
#                                                vid.mp4                         # video
#                                                screen                          # screenshot
#                                                path/                           # directory
#                                                list.txt                        # list of images
#                                                list.streams                    # list of streams
#                                                'path/*.jpg'                    # glob
#                                                'https://youtu.be/LNwODJXcvt4'  # YouTube
#                                                'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream

# !python /content/yolov5/detect.py --weights /content/yolov5/runs/train/exp2/weights/best.pt --conf 0.75 --iou-thres 0.25  --source /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4
# Out:
# detect: weights=['/content/yolov5/runs/train/exp2/weights/best.pt'], source=/content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.75, iou_thres=0.25, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-224-g6262c7f Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# Model summary: 322 layers, 86220517 parameters, 0 gradients, 203.9 GFLOPs
# video 1/1 (1/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 44.7ms
# video 1/1 (2/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (3/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (4/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (5/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (6/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.2ms
# video 1/1 (7/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.1ms
# video 1/1 (8/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 16.9ms
# video 1/1 (9/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (10/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 16.0ms
# video 1/1 (11/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (12/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.1ms
# video 1/1 (13/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (14/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (15/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (16/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 16.7ms
# video 1/1 (17/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (18/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 16.2ms
# video 1/1 (19/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (20/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (21/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (22/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (23/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (24/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 17.2ms
# video 1/1 (25/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (26/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 17.0ms
# video 1/1 (27/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (28/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (29/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (30/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (31/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (32/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 16.2ms
# video 1/1 (33/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (34/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 16.5ms
# video 1/1 (35/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (36/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (37/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (38/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (39/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (40/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 15.7ms
# video 1/1 (41/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.1ms
# video 1/1 (42/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.1ms
# video 1/1 (43/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (44/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 15.5ms
# video 1/1 (45/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.1ms
# video 1/1 (46/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (47/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.1ms
# video 1/1 (48/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (49/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (50/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (51/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (52/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (53/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (54/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.1ms
# video 1/1 (55/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (56/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (57/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.1ms
# video 1/1 (58/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (59/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.4ms
# video 1/1 (60/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.1ms
# video 1/1 (61/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (62/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (63/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (64/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (65/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (66/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (67/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (68/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (69/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.1ms
# video 1/1 (70/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (71/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (72/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (73/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.3ms
# video 1/1 (74/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.1ms
# video 1/1 (75/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (76/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (77/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (78/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (79/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (80/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (81/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (82/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (83/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (84/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (85/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (86/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (87/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (88/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (89/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (90/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (91/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (92/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (93/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (94/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (95/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (96/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (97/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (98/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (99/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (100/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 1000, 14.0ms
# video 1/1 (101/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (102/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (103/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (104/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.1ms
# video 1/1 (105/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (106/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (107/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (108/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (109/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (110/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (111/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (112/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (113/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (114/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (115/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (116/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (117/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (118/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (119/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (120/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (121/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (122/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (123/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (124/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (125/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (126/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (127/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (128/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (129/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (130/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.1ms
# video 1/1 (131/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (132/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (133/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (134/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (135/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (136/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (137/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (138/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.9ms
# video 1/1 (139/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (140/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (141/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (142/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (143/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (144/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (145/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (146/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (147/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (148/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (149/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (150/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (151/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (152/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (153/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (154/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (155/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (156/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (157/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (158/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (159/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (160/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (161/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (162/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (163/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.1ms
# video 1/1 (164/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (165/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (166/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (167/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (168/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (169/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (170/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (171/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (172/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (173/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (174/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (175/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (176/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (177/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (178/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (179/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (180/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (181/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.1ms
# video 1/1 (182/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (183/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (184/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.4ms
# video 1/1 (185/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.1ms
# video 1/1 (186/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (187/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (188/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (189/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (190/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (191/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (192/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (193/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (194/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (195/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (196/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (197/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (198/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.2ms
# video 1/1 (199/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (200/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (201/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (202/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (203/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (204/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (205/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (206/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (207/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (208/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (209/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (210/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (211/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (212/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (213/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (214/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (215/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (216/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 13.9ms
# video 1/1 (217/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (218/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (219/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (220/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (221/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (222/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (223/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.1ms
# video 1/1 (224/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (225/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (226/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (227/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (228/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (229/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (230/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (231/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (232/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (233/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (234/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (235/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (236/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (237/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (238/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (239/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (240/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (241/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 13.9ms
# video 1/1 (242/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (243/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (244/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (245/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (246/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (247/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (248/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (249/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (250/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (251/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (252/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (253/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (254/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (255/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (256/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (257/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (258/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (259/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (260/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (261/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (262/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (263/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (264/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (265/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (266/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (267/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (268/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (269/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (270/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (271/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (272/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (273/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (274/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (275/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (276/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (277/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (278/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 16.2ms
# video 1/1 (279/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 1000, 14.0ms
# video 1/1 (280/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (281/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (282/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (283/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (284/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (285/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (286/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (287/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (288/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (289/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (290/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (291/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (292/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (293/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (294/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (295/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (296/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (297/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (298/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.1ms
# video 1/1 (299/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (300/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.3ms
# video 1/1 (301/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (302/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (303/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (304/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (305/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (306/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (307/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (308/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (309/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (310/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (311/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (312/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (313/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 13.9ms
# video 1/1 (314/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (315/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (316/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 16.0ms
# video 1/1 (317/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (318/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (319/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (320/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (321/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (322/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 50000, 14.0ms
# video 1/1 (323/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (324/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 16.4ms
# video 1/1 (325/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 50000, 14.0ms
# video 1/1 (326/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 15.0ms
# video 1/1 (327/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.5ms
# video 1/1 (328/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 10000, 14.0ms
# video 1/1 (329/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (330/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (331/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 13.9ms
# video 1/1 (332/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 15.6ms
# video 1/1 (333/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (334/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.1ms
# video 1/1 (335/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (336/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (337/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (338/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (339/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (340/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 15.5ms
# video 1/1 (341/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (342/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (343/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.3ms
# video 1/1 (344/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (345/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 13.9ms
# video 1/1 (346/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (347/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 1000, 14.0ms
# video 1/1 (348/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 15.4ms
# video 1/1 (349/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (350/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (351/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (352/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (353/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (354/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 1000, 1 10000, 14.0ms
# video 1/1 (355/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (356/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 15.6ms
# video 1/1 (357/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (358/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (359/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (360/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 1000, 14.0ms
# video 1/1 (361/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (362/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (363/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (364/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 15.9ms
# video 1/1 (365/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.1ms
# video 1/1 (366/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (367/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (368/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 1000, 14.0ms
# video 1/1 (369/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 1000, 14.0ms
# video 1/1 (370/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 1000, 14.0ms
# video 1/1 (371/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 1000, 13.9ms
# video 1/1 (372/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 15.9ms
# video 1/1 (373/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 1000, 14.0ms
# video 1/1 (374/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (375/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 1000, 14.0ms
# video 1/1 (376/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (377/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 1 1000, 14.0ms
# video 1/1 (378/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (379/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (380/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 15.6ms
# video 1/1 (381/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (382/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (383/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (384/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (385/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (386/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 13.9ms
# video 1/1 (387/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (388/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 15.5ms
# video 1/1 (389/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (390/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (391/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (392/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (393/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (394/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (395/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (396/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 15.1ms
# video 1/1 (397/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (398/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (399/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (400/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (401/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (402/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.1ms
# video 1/1 (403/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (404/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 16.4ms
# video 1/1 (405/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (406/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (407/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (408/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (409/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (410/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (411/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 13.9ms
# video 1/1 (412/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 15.3ms
# video 1/1 (413/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (414/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (415/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (416/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (417/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (418/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (419/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (420/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (421/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (422/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (423/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (424/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# video 1/1 (425/425) /content/drive/MyDrive/mp3/KakaoTalk_20230922_135042395.mp4: 640x384 (no detections), 14.0ms
# Speed: 0.5ms pre-process, 14.2ms inference, 0.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %%
shutil.move('/content/yolov5/runs/detect/exp2', '/content/drive/MyDrive/mp3')
# Out:
# '/content/drive/MyDrive/mp3/exp2'

# %%
## 소스 파일
#!python detect.py --weights best.pt --source path/to/images

# %%
########################
# 이 셀부터 코드 작성하세요
########################
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img-size 640 --conf 0.4 --source /content/money_data/KakaoTalk_20230921_163159696.jpg

# %% [markdown]
# ## 5. 실시간 데모

# %% [markdown]
# - Ultralytics HUB App
#
# - NNAPI
#
# - Android | Pytorch
#
# - deeplearning model for mobile

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
cap = cv2.VideoCapture(2)

model = YOLO(model='/content/drive/MyDrive/mp3/best.pt', task='detect')
while True:
  ret, img = cap.read()
  result = model.predict(source=img, conf=0.25, iou=0.7, save=False,
                         line_width=2, verbose=False)
  img = result[0].plot()

  cv2.imshow('Bill Detection', img)

  if cv2.waitKey(10) == ord('q'):
    break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-092d6bef6f4f> in <cell line: 1>()
# ----> 1 from ultralytics import YOLO
#       2 cap = cv2.VideoCapture(2)
#       3
#       4 model = YOLO(model='/content/drive/MyDrive/mp3/best.pt', task='detect')
#       5 while True:
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/__init__.py in <module>
#       3 __version__ = '8.0.192'
#       4
# ----> 5 from ultralytics.models import RTDETR, SAM, YOLO
#       6 from ultralytics.models.fastsam import FastSAM
#       7 from ultralytics.models.nas import NAS
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/models/__init__.py in <module>
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
#       2
# ----> 3 from .rtdetr import RTDETR
#       4 from .sam import SAM
#       5 from .yolo import YOLO
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/models/rtdetr/__init__.py in <module>
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
#       2
# ----> 3 from .model import RTDETR
#       4 from .predict import RTDETRPredictor
#       5 from .val import RTDETRValidator
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/models/rtdetr/model.py in <module>
#       3 RT-DETR model interface
#       4 """
# ----> 5 from ultralytics.engine.model import Model
#       6 from ultralytics.nn.tasks import RTDETRDetectionModel
#       7
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py in <module>
#       6 from typing import Union
#       7
# ----> 8 from ultralytics.cfg import TASK2DATA, get_cfg, get_save_dir
#       9 from ultralytics.hub.utils import HUB_WEB_ROOT
#      10 from ultralytics.nn.tasks import attempt_load_one_weight, guess_model_task, nn, yaml_model_load
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py in <module>
#       8 from typing import Dict, List, Union
#       9
# ---> 10 from ultralytics.utils import (ASSETS, DEFAULT_CFG, DEFAULT_CFG_DICT, DEFAULT_CFG_PATH, LOGGER, RANK, ROOT, SETTINGS,
#      11                                SETTINGS_YAML, TESTS_RUNNING, IterableSimpleNamespace, __version__, checks, colorstr,
#      12                                deprecation_warn, yaml_load, yaml_print)
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/utils/__init__.py in <module>
#      19 import matplotlib.pyplot as plt
#      20 import numpy as np
# ---> 21 import torch
#      22 import yaml
#      23 from tqdm import tqdm as tqdm_original
#
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py in <module>
#    1463 from . import library
#    1464 if not TYPE_CHECKING:
# -> 1465     from . import _meta_registrations
#    1466
#    1467 # Enable CUDA Sanitizer
#
# /usr/local/lib/python3.10/dist-packages/torch/_meta_registrations.py in <module>
#       5 import torch._prims_common as utils
#       6 from torch import Tensor
# ----> 7 from torch._decomp import _add_op_to_registry, global_decomposition_table, meta_table
#       8 from torch._ops import OpOverload
#       9 from torch._prims import _elementwise_meta, ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND
#
# /usr/local/lib/python3.10/dist-packages/torch/_decomp/__init__.py in <module>
#     167
#     168 # populate the table
# --> 169 import torch._decomp.decompositions
#     170 import torch._refs
#     171
#
# /usr/local/lib/python3.10/dist-packages/torch/_decomp/decompositions.py in <module>
#       8
#       9 import torch
# ---> 10 import torch._prims as prims
#      11 import torch._prims_common as utils
#      12 import torch.nn.functional as F
#
# /usr/local/lib/python3.10/dist-packages/torch/_prims/__init__.py in <module>
#      31 )
#      32 from torch._prims_common.wrappers import backwards_not_supported
# ---> 33 from torch._subclasses.fake_tensor import FakeTensor, FakeTensorMode
#      34 from torch.overrides import handle_torch_function, has_torch_function
#      35 from torch.utils._pytree import tree_flatten, tree_map, tree_unflatten
#
# /usr/local/lib/python3.10/dist-packages/torch/_subclasses/__init__.py in <module>
#       1 import torch
#       2
# ----> 3 from torch._subclasses.fake_tensor import (
#       4     DynamicOutputShapeException,
#       5     FakeTensor,
#
# /usr/local/lib/python3.10/dist-packages/torch/_subclasses/fake_tensor.py in <module>
#      11
#      12 import torch
# ---> 13 from torch._guards import Source
#      14 from torch._ops import OpOverload
#      15 from torch._prims_common import (
#
# /usr/local/lib/python3.10/dist-packages/torch/_guards.py in <module>
#      12 # but mypy complains.
#      13 try:
# ---> 14     import sympy  # type: ignore[import]
#      15 except ImportError:
#      16     log.warning("No sympy found")
#
# /usr/local/lib/python3.10/dist-packages/sympy/__init__.py in <module>
#     150         continued_fraction_convergents, continued_fraction, egyptian_fraction)
#     151
# --> 152 from .concrete import product, Product, summation, Sum
#     153
#     154 from .discrete import (fft, ifft, ntt, intt, fwht, ifwht, mobius_transform,
#
# /usr/local/lib/python3.10/dist-packages/sympy/concrete/__init__.py in <module>
# ----> 1 from .products import product, Product
#       2 from .summations import summation, Sum
#       3
#       4 __all__ = [
#       5     'product', 'Product',
#
# /usr/local/lib/python3.10/dist-packages/sympy/concrete/products.py in <module>
#       2
#       3 from .expr_with_intlimits import ExprWithIntLimits
# ----> 4 from .summations import Sum, summation, _dummy_with_inherited_properties_concrete
#       5 from sympy.core.expr import Expr
#       6 from sympy.core.exprtools import factor_terms
#
# /usr/local/lib/python3.10/dist-packages/sympy/concrete/summations.py in <module>
#      24 from sympy.functions.special.tensor_functions import KroneckerDelta
#      25 from sympy.functions.special.zeta_functions import zeta
# ---> 26 from sympy.integrals.integrals import Integral
#      27 from sympy.logic.boolalg import And
#      28 from sympy.polys.partfrac import apart
#
# /usr/local/lib/python3.10/dist-packages/sympy/integrals/__init__.py in <module>
#      11     -cos(x)
#      12 """
# ---> 13 from .integrals import integrate, Integral, line_integrate
#      14 from .transforms import (mellin_transform, inverse_mellin_transform,
#      15                         MellinTransform, InverseMellinTransform,
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.10/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.10/importlib/_bootstrap_external.py in get_code(self, fullname)
#
# /usr/lib/python3.10/importlib/_bootstrap_external.py in get_data(self, path)
#
# KeyboardInterrupt:

# %% [markdown]
# ###모델 변환

# %% [markdown]
# 1.PyTorch에서 ONNX로 변환

# %%
# !pip uninstall torch torchvision
# !pip install torch torchvision

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# !pip install -r yolov5/requirements.txt  # install

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
import sys

# YOLOv5 디렉토리 경로를 sys.path에 추가
sys.path.append('./yolov5/')

# %%
# !pip install onnx
# Out:
# Collecting onnx
#   Downloading onnx-1.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 68.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from onnx) (1.23.5)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from onnx) (3.20.3)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.10/dist-packages (from onnx) (4.5.0)
# Installing collected packages: onnx
# Successfully installed onnx-1.14.1

# %%
# 필요한 모듈들을 임포트
import torch
from models.experimental import attempt_load  # attempt_load 함수 임포트

# 모델 로드
model_path = '/content/drive/MyDrive/mp3/best.pt'
model = attempt_load(model_path)
model = model.to('cuda')  # 모델을 GPU로 이동
model.eval()  # 평가 모드로 설정

dummy_input = torch.randn(1, 3, 416, 416).to('cuda')  # Assuming model takes 416x416 RGB images and move it to GPU

model = model.cpu()
dummy_input = dummy_input.cpu()

torch.onnx.export(model, dummy_input, "model.onnx")
# Out:
# Fusing layers...
# Model summary: 322 layers, 86220517 parameters, 0 gradients, 203.9 GFLOPs
# /content/yolov5/models/yolo.py:207: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if augment:
# /content/yolov5/models/yolo.py:119: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if profile:
# /content/yolov5/models/yolo.py:123: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if visualize:
# /content/yolov5/models/yolo.py:123: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if visualize:
# /content/yolov5/models/yolo.py:119: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if profile:
# /content/yolov5/models/yolo.py:64: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if self.dynamic or self.grid[i].shape[2:4] != x[i].shape[2:4]:
# ============= Diagnostic Run torch.onnx.export version 2.0.1+cu117 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================

# %% [markdown]
# 2.ONNX에서 CoreML로 변환

# %%
# !pip install coremltools

# %%
# !pip install onnx-coreml
# Out:
# Collecting onnx-coreml
#   Downloading onnx_coreml-1.3-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from onnx-coreml) (8.1.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from onnx-coreml) (1.23.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnx-coreml) (1.12)
# Requirement already satisfied: onnx>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from onnx-coreml) (1.14.1)
# Collecting typing>=3.6.4 (from onnx-coreml)
#   Downloading typing-3.7.4.3.tar.gz (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 6.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.10/dist-packages (from onnx-coreml) (4.5.0)
# Requirement already satisfied: coremltools>=3.2 in /usr/local/lib/python3.10/dist-packages (from onnx-coreml) (7.0)
# Requirement already satisfied: protobuf<=4.0.0,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from coremltools>=3.2->onnx-coreml) (3.20.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from coremltools>=3.2->onnx-coreml) (4.66.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from coremltools>=3.2->onnx-coreml) (23.1)
# Requirement already satisfied: attrs>=21.3.0 in /usr/local/lib/python3.10/dist-packages (from coremltools>=3.2->onnx-coreml) (23.1.0)
# Requirement already satisfied: cattrs in /usr/local/lib/python3.10/dist-packages (from coremltools>=3.2->onnx-coreml) (23.1.2)
# Requirement already satisfied: pyaml in /usr/local/lib/python3.10/dist-packages (from coremltools>=3.2->onnx-coreml) (23.9.7)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnx-coreml) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from cattrs->coremltools>=3.2->onnx-coreml) (1.1.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from pyaml->coremltools>=3.2->onnx-coreml) (6.0.1)
# Building wheels for collected packages: typing
#   Building wheel for typing (setup.py) ... done
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26305 sha256=fc97569e576eeb87e5c5562255c1005b78a6fad460e40d61d06eb5bf47230ef6
#   Stored in directory: /root/.cache/pip/wheels/7c/d0/9e/1f26ebb66d9e1732e4098bc5a6c2d91f6c9a529838f0284890
# Successfully built typing
# Installing collected packages: typing, onnx-coreml
# Successfully installed onnx-coreml-1.3 typing-3.7.4.3

# %%
import coremltools
from onnx_coreml import convert

coreml_model = convert(model='model.onnx',
                       mode='classifier',  # or 'regressor' based on your task
                       image_input_names=['image'],
                       preprocessing_args={'image_scale': 1/255.0})
coreml_model.save('model.mlmodel')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-2cddb556c76c> in <cell line: 2>()
#       1 import coremltools
# ----> 2 from onnx_coreml import convert
#       3
#       4 coreml_model = convert(model='model.onnx',
#       5                        mode='classifier',  # or 'regressor' based on your task
#
# /usr/local/lib/python3.10/dist-packages/onnx_coreml/__init__.py in <module>
#       4 from __future__ import unicode_literals
#       5
# ----> 6 from .converter import convert
#       7
#       8 # onnx-coreml version
#
# /usr/local/lib/python3.10/dist-packages/onnx_coreml/converter.py in <module>
#      33
#      34 # ML model passes
# ---> 35 from coremltools.converters.nnssa.coreml.graph_pass.mlmodel_passes import remove_disconnected_layers, transform_conv_crop
#      36
#      37 from ._error_utils import ErrorHandling
#
# ModuleNotFoundError: No module named 'coremltools.converters.nnssa'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
